# %% [markdown]
# # Task for the identification of argumentative sentence types with a multilabel approach

# %% [markdown]
# Files needed to run the notebook:
#
# - The pickle file *dataset.pkl*;

# %% [markdown]
# Import libraries:

# %%
import pickle as pkl
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf
import os
import json
import numpy as np

from sentence_transformers import SentenceTransformer
from sklearn.model_selection import train_test_split

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout, LSTM
from tensorflow.keras.regularizers import l2

# %%
df = pd.read_pickle("./dataset.pkl")

# %%
df.head()
# Out:
#   Document  Name  Id                                           Sentence Type  \
# 2     2004  prem  A3  respect borne mind pursuant Article 58 Statute...    L
# 3     2004  prem  A4  Advocate General states point 20 Opinion Commi...    F
# 5     2004  prem  A6  Regarding Wam’s argument Commission’s appeal i...  L|F
# 6     2004  prem  A7  Appeals judgments Court First Instance governe...    L
# 7     2004  prem  A8  Next must noted obligation provide statement r...    L
#
#   Supported_by Supported_from_failure Attacked_by Inhibited_by Rephrased_by  \
# 2          NaN                    NaN         NaN          NaN          NaN
# 3          NaN                    NaN         NaN          NaN          NaN
# 5          NaN                    NaN         NaN          NaN          NaN
# 6          NaN                    NaN         NaN          NaN          NaN
# 7          NaN                    NaN         NaN          NaN          NaN
#
#   Argumentation_scheme
# 2                 Rule
# 3                  Aut
# 5                 Rule
# 6                 Rule
# 7                 Prec

# %%
df["Argumentation_scheme"].values[0]
# Out:
# 'Rule'

# %%
df["Argumentation_scheme"].value_counts()
# Out:
# Prec                  279
# Itpr                   95
# Princ                  64
# Rule                   61
# Prec|Rule              35
# Itpr|Prec              22
# Aut                    21
# Class|Prec|Rule         9
# Tele                    8
# Class                   7
# Class|Prec              5
# Aut|Itpr                5
# Prec|Tele               5
# Itpr|Tele               4
# Rule|Syst               3
# Itpr|Rule               3
# Prec|Syst               3
# Syst                    3
# Princ|Rule              2
# Psy|Tele                2
# Lit|Rule                2
# Lit|Prec                2
# Prec|Psy|Rule|Tele      1
# Princ|Tele              1
# Itpr|Syst               1
# Itpr|Psy                1
# Itpr|Lit                1
# Aut|Prec|Princ          1
# Princ|Psy|Syst          1
# Itpr|Princ|Syst         1
# Lit|Rule|Syst           1
# Syst|Tele               1
# Aut|Class               1
# Lit|Rule|Tele           1
# Aut|Itpr|Prec           1
# Prec|Psy                1
# Aut|Rule                1
# Aut|Syst                1
# Lit                     1
# Prec|Princ              1
# Psy|Rule                1
# Aut|Prec                1
# Class|Rule              1
# Rule|Tele               1
# Itpr|Prec|Rule          1
# Name: Argumentation_scheme, dtype: int64

# %%
value_counts = df['Argumentation_scheme'].value_counts() # Specific column 
df_truncated60 = df[df['Argumentation_scheme'].isin(value_counts[value_counts > 60].index)]
df_truncated20 = df[df['Argumentation_scheme'].isin(value_counts[value_counts > 20].index)]

# %%
df_truncated60['Argumentation_scheme'].value_counts()
# Out:
# Prec     279
# Itpr      95
# Princ     64
# Rule      61
# Name: Argumentation_scheme, dtype: int64

# %%
df_truncated20['Argumentation_scheme'].value_counts()
# Out:
# Prec         279
# Itpr          95
# Princ         64
# Rule          61
# Prec|Rule     35
# Itpr|Prec     22
# Aut           21
# Name: Argumentation_scheme, dtype: int64

# %%
df_balanced = pd.concat([df[df["Argumentation_scheme"] == "Prec"].sample(61),
                    df[df["Argumentation_scheme"] == "Itpr"].sample(61),
                    df[df["Argumentation_scheme"] == "Princ"].sample(61),
                    df[df["Argumentation_scheme"] == "Rule"]
                    ])

# %%
df_balanced["Argumentation_scheme"].value_counts()
# Out:
# Prec     61
# Itpr     61
# Princ    61
# Rule     61
# Name: Argumentation_scheme, dtype: int64

# %% [markdown]
# Choice of parameters:

# %%
# EMBEDDINGS
EMBEDDING = "legal_bert_sentence"

# MODELS
MODEL = "RNN"

# DATASET (uncomment the chosen one)
# DATASET = df
DATASET = df_truncated60
# DATASET = df_truncated20
# DATASET = df_balanced

TEST_SIZE = 0.3
VAL_SIZE = 0.2  # percentage taken from the train subset

# MODEL PARAMETERS

EPOCHS = 250
BATCH_SIZE = 64
LR = 0.0001
DROP = 0.1

L2_FACTOR = 0.001
LAYERS = [512, 256, 128] # 3 layers

# %%
aut_col = df['Argumentation_scheme'].apply(lambda x: 1 if 'Aut' in str(x) else 0)
class_col = df['Argumentation_scheme'].apply(lambda x: 1 if 'Class' in str(x) else 0)
itpr_col = df['Argumentation_scheme'].apply(lambda x: 1 if 'Itpr' in str(x) else 0)
lit_col = df['Argumentation_scheme'].apply(lambda x: 1 if 'Lit' in str(x) else 0)
prec_col = df['Argumentation_scheme'].apply(lambda x: 1 if 'Prec' in str(x) else 0)
princ_col = df['Argumentation_scheme'].apply(lambda x: 1 if 'Princ' in str(x) else 0)
psy_col = df['Argumentation_scheme'].apply(lambda x: 1 if 'Psy' in str(x) else 0)
rule_col = df['Argumentation_scheme'].apply(lambda x: 1 if 'Rule' in str(x) else 0)
syst_col = df['Argumentation_scheme'].apply(lambda x: 1 if 'Syst' in str(x) else 0)
tele_col = df['Argumentation_scheme'].apply(lambda x: 1 if 'Tele' in str(x) else 0)

df_new = pd.DataFrame(DATASET['Sentence'])
df_new['Aut'] = aut_col
df_new['Class'] = class_col
df_new['Itpr'] = itpr_col
df_new['Lit'] = lit_col
df_new['Prec'] = prec_col
df_new['Princ'] = princ_col
df_new['Psy'] = psy_col
df_new['Rule'] = rule_col
df_new['Syst'] = syst_col
df_new['Tele'] = tele_col

# %%
df_new.head()
# Out:
#                                              Sentence  Aut  Class  Itpr  Lit  \
# 2   respect borne mind pursuant Article 58 Statute...    0      0     0    0
# 5   Regarding Wam’s argument Commission’s appeal i...    0      0     0    0
# 6   Appeals judgments Court First Instance governe...    0      0     0    0
# 7   Next must noted obligation provide statement r...    0      0     0    0
# 11  According settled caselaw statement reasons re...    0      0     0    0
#
#     Prec  Princ  Psy  Rule  Syst  Tele
# 2      0      0    0     1     0     0
# 5      0      0    0     1     0     0
# 6      0      0    0     1     0     0
# 7      1      0    0     0     0     0
# 11     1      0    0     0     0     0

# %% [markdown]
# # Embedding

# %%
if EMBEDDING == "legal_bert_sentence":
  sbert_model = SentenceTransformer("nlpaueb/legal-bert-small-uncased")
  sentence_embeddings = sbert_model.encode(df_new["Sentence"].values)

  X = sentence_embeddings
  X = X.reshape(len(X), 1, X.shape[1])
  y = df_new.drop("Sentence", axis=1)
# Out:
# WARNING:root:No sentence-transformers model found with name /root/.cache/torch/sentence_transformers/nlpaueb_legal-bert-small-uncased. Creating a new one with MEAN pooling.
# Some weights of the model checkpoint at /root/.cache/torch/sentence_transformers/nlpaueb_legal-bert-small-uncased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'cls.predictions.decoder.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
print("EMBEDDING: ", EMBEDDING)
print("SHAPE X: ", X.shape)
print("SHAPE y: ", y.shape)
# Out:
# EMBEDDING:  legal_bert_sentence
# SHAPE X:  (499, 1, 512)
# SHAPE y:  (499, 10)

# %% [markdown]
# # Training

# %%
if MODEL == "RNN":
  INPUTS = X.shape[-1]
  OUTPUTS = y.shape[-1]

  def create_deep_model(factor, rate):
      model = Sequential()      
      model.add(LSTM(units=LAYERS[0], return_sequences = True, input_dim=INPUTS,kernel_initializer='he_uniform', kernel_regularizer=l2(factor), 
        activation='relu')), Dropout(rate),
      model.add(LSTM(units=LAYERS[1], return_sequences = True, kernel_regularizer=l2(factor),
        activation='relu')), Dropout(rate),
      model.add(LSTM(units=LAYERS[2], kernel_regularizer=l2(factor),
        activation='relu')), Dropout(rate),
      #Output layer
      model.add(Dense(units=OUTPUTS, activation='softmax'))
      return model
  model= create_deep_model(factor=L2_FACTOR, rate=DROP)

  opt=tf.keras.optimizers.Adam(learning_rate=LR)
  model.compile(loss='kullback_leibler_divergence', optimizer=opt,   
  metrics=['accuracy'])

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=TEST_SIZE, shuffle= True)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=VAL_SIZE, shuffle= True)

#fit the model
history=model.fit(x=X_train, y=y_train, batch_size=BATCH_SIZE, epochs=EPOCHS, validation_data=(X_val, y_val), verbose=1)
# Out:
# Epoch 1/250
# 5/5 [==============================] - 5s 224ms/step - loss: 7.3938 - accuracy: 0.1075 - val_loss: 7.3406 - val_accuracy: 0.1286
# Epoch 2/250
# 5/5 [==============================] - 0s 74ms/step - loss: 7.3136 - accuracy: 0.2294 - val_loss: 7.2608 - val_accuracy: 0.5857
# Epoch 3/250
# 5/5 [==============================] - 0s 70ms/step - loss: 7.2342 - accuracy: 0.5484 - val_loss: 7.1816 - val_accuracy: 0.5714
# Epoch 4/250
# 5/5 [==============================] - 0s 70ms/step - loss: 7.1552 - accuracy: 0.5627 - val_loss: 7.1029 - val_accuracy: 0.5857
# Epoch 5/250
# 5/5 [==============================] - 0s 66ms/step - loss: 7.0767 - accuracy: 0.5627 - val_loss: 7.0243 - val_accuracy: 0.5857
# Epoch 6/250
# 5/5 [==============================] - 0s 65ms/step - loss: 6.9981 - accuracy: 0.5627 - val_loss: 6.9452 - val_accuracy: 0.5857
# Epoch 7/250
# 5/5 [==============================] - 0s 73ms/step - loss: 6.9188 - accuracy: 0.5627 - val_loss: 6.8650 - val_accuracy: 0.5857
# Epoch 8/250
# 5/5 [==============================] - 0s 70ms/step - loss: 6.8383 - accuracy: 0.5627 - val_loss: 6.7827 - val_accuracy: 0.5857
# Epoch 9/250
# 5/5 [==============================] - 0s 67ms/step - loss: 6.7553 - accuracy: 0.5627 - val_loss: 6.6969 - val_accuracy: 0.5857
# Epoch 10/250
# Epoch 169/250
# 5/5 [==============================] - 0s 68ms/step - loss: 1.0633 - accuracy: 1.0000 - val_loss: 1.9522 - val_accuracy: 0.7857
# Epoch 170/250
# 5/5 [==============================] - 0s 69ms/step - loss: 1.0559 - accuracy: 1.0000 - val_loss: 1.9551 - val_accuracy: 0.7857
# Epoch 171/250
# 5/5 [==============================] - 0s 71ms/step - loss: 1.0485 - accuracy: 1.0000 - val_loss: 1.9538 - val_accuracy: 0.7857
# Epoch 172/250
# 5/5 [==============================] - 0s 69ms/step - loss: 1.0416 - accuracy: 1.0000 - val_loss: 1.9357 - val_accuracy: 0.8000
# Epoch 173/250
# 5/5 [==============================] - 0s 73ms/step - loss: 1.0345 - accuracy: 1.0000 - val_loss: 1.9314 - val_accuracy: 0.7714
# Epoch 174/250
# 5/5 [==============================] - 0s 75ms/step - loss: 1.0280 - accuracy: 1.0000 - val_loss: 1.9404 - val_accuracy: 0.8000
# Epoch 175/250
# 5/5 [==============================] - 0s 77ms/step - loss: 1.0205 - accuracy: 1.0000 - val_loss: 1.9147 - val_accuracy: 0.7857
# Epoch 176/250
# 5/5 [==============================] - 0s 71ms/step - loss: 1.0147 - accuracy: 1.0000 - val_loss: 1.9229 - val_accuracy: 0.7857
# Epoch 177/250
# 5/5 [==============================] - 0s 69ms/step - loss: 1.0064 - accuracy: 1.0000 - val_loss: 1.9203 - val_accuracy: 0.7714
# Epoch 178/250
# 5/5 [==============================] - 0s 69ms/step - loss: 1.0002 - accuracy: 1.0000 - val_loss: 1.9123 - val_accuracy: 0.7714
# Epoch 179/250
# 5/5 [==============================] - 0s 68ms/step - loss: 0.9929 - accuracy: 1.0000 - val_loss: 1.8841 - val_accuracy: 0.7857
# Epoch 180/250
# 5/5 [==============================] - 0s 70ms/step - loss: 0.9865 - accuracy: 1.0000 - val_loss: 1.8924 - val_accuracy: 0.7857
# Epoch 181/250
# 5/5 [==============================] - 0s 72ms/step - loss: 0.9795 - accuracy: 1.0000 - val_loss: 1.8796 - val_accuracy: 0.7714
# Epoch 182/250
# 5/5 [==============================] - 0s 72ms/step - loss: 0.9730 - accuracy: 1.0000 - val_loss: 1.8769 - val_accuracy: 0.8143
# Epoch 183/250
# 5/5 [==============================] - 0s 69ms/step - loss: 0.9665 - accuracy: 1.0000 - val_loss: 1.8700 - val_accuracy: 0.7714
# Epoch 184/250
# 5/5 [==============================] - 0s 71ms/step - loss: 0.9600 - accuracy: 1.0000 - val_loss: 1.8676 - val_accuracy: 0.8000
# Epoch 185/250
# 5/5 [==============================] - 0s 72ms/step - loss: 0.9536 - accuracy: 1.0000 - val_loss: 1.8496 - val_accuracy: 0.7857
# Epoch 186/250
# 5/5 [==============================] - 0s 68ms/step - loss: 0.9473 - accuracy: 1.0000 - val_loss: 1.8463 - val_accuracy: 0.7714
# Epoch 187/250
# 5/5 [==============================] - 0s 71ms/step - loss: 0.9412 - accuracy: 1.0000 - val_loss: 1.8441 - val_accuracy: 0.7714
# Epoch 188/250
# 5/5 [==============================] - 0s 80ms/step - loss: 0.9351 - accuracy: 1.0000 - val_loss: 1.8427 - val_accuracy: 0.7714
# Epoch 189/250
# 5/5 [==============================] - 0s 71ms/step - loss: 0.9289 - accuracy: 1.0000 - val_loss: 1.8281 - val_accuracy: 0.8000
# Epoch 190/250
# 5/5 [==============================] - 0s 70ms/step - loss: 0.9228 - accuracy: 1.0000 - val_loss: 1.8220 - val_accuracy: 0.7714
# Epoch 191/250
# 5/5 [==============================] - 0s 70ms/step - loss: 0.9167 - accuracy: 1.0000 - val_loss: 1.8269 - val_accuracy: 0.8000
# Epoch 192/250
# 5/5 [==============================] - 0s 67ms/step - loss: 0.9109 - accuracy: 1.0000 - val_loss: 1.8035 - val_accuracy: 0.7857
# Epoch 193/250
# 5/5 [==============================] - 0s 72ms/step - loss: 0.9051 - accuracy: 1.0000 - val_loss: 1.8026 - val_accuracy: 0.8000
# Epoch 194/250
# 5/5 [==============================] - 0s 74ms/step - loss: 0.8993 - accuracy: 1.0000 - val_loss: 1.8012 - val_accuracy: 0.7857
# Epoch 195/250
# 5/5 [==============================] - 0s 70ms/step - loss: 0.8935 - accuracy: 1.0000 - val_loss: 1.7983 - val_accuracy: 0.7857
# Epoch 196/250
# 5/5 [==============================] - 0s 68ms/step - loss: 0.8880 - accuracy: 1.0000 - val_loss: 1.7823 - val_accuracy: 0.7857
# Epoch 197/250
# 5/5 [==============================] - 0s 72ms/step - loss: 0.8820 - accuracy: 1.0000 - val_loss: 1.7856 - val_accuracy: 0.7857
# Epoch 198/250
# 5/5 [==============================] - 0s 66ms/step - loss: 0.8767 - accuracy: 1.0000 - val_loss: 1.7849 - val_accuracy: 0.7714
# Epoch 199/250
# 5/5 [==============================] - 0s 70ms/step - loss: 0.8710 - accuracy: 1.0000 - val_loss: 1.7603 - val_accuracy: 0.7857
# Epoch 200/250
# 5/5 [==============================] - 0s 73ms/step - loss: 0.8655 - accuracy: 1.0000 - val_loss: 1.7894 - val_accuracy: 0.7857
# Epoch 201/250
# 5/5 [==============================] - 0s 67ms/step - loss: 0.8598 - accuracy: 1.0000 - val_loss: 1.7777 - val_accuracy: 0.7714
# Epoch 202/250
# 5/5 [==============================] - 0s 68ms/step - loss: 0.8546 - accuracy: 1.0000 - val_loss: 1.7589 - val_accuracy: 0.8143
# Epoch 203/250
# 5/5 [==============================] - 0s 74ms/step - loss: 0.8490 - accuracy: 1.0000 - val_loss: 1.7552 - val_accuracy: 0.7714
# Epoch 204/250
# 5/5 [==============================] - 0s 68ms/step - loss: 0.8444 - accuracy: 1.0000 - val_loss: 1.7575 - val_accuracy: 0.7714
# Epoch 205/250
# 5/5 [==============================] - 0s 68ms/step - loss: 0.8384 - accuracy: 1.0000 - val_loss: 1.7352 - val_accuracy: 0.7857
# Epoch 206/250
# 5/5 [==============================] - 0s 74ms/step - loss: 0.8339 - accuracy: 1.0000 - val_loss: 1.7330 - val_accuracy: 0.7857
# Epoch 207/250
# 5/5 [==============================] - 0s 69ms/step - loss: 0.8278 - accuracy: 1.0000 - val_loss: 1.7468 - val_accuracy: 0.7714
# Epoch 208/250
# 5/5 [==============================] - 0s 68ms/step - loss: 0.8228 - accuracy: 1.0000 - val_loss: 1.7235 - val_accuracy: 0.8000
# Epoch 209/250
# 5/5 [==============================] - 0s 74ms/step - loss: 0.8177 - accuracy: 1.0000 - val_loss: 1.7185 - val_accuracy: 0.7857
# Epoch 210/250
# 5/5 [==============================] - 0s 70ms/step - loss: 0.8125 - accuracy: 1.0000 - val_loss: 1.7223 - val_accuracy: 0.7714
# Epoch 211/250
# 5/5 [==============================] - 0s 66ms/step - loss: 0.8080 - accuracy: 1.0000 - val_loss: 1.7084 - val_accuracy: 0.7857
# Epoch 212/250
# 5/5 [==============================] - 0s 78ms/step - loss: 0.8030 - accuracy: 1.0000 - val_loss: 1.7145 - val_accuracy: 0.8000
# Epoch 213/250
# 5/5 [==============================] - 0s 68ms/step - loss: 0.7983 - accuracy: 1.0000 - val_loss: 1.7060 - val_accuracy: 0.7857
# Epoch 214/250
# 5/5 [==============================] - 0s 65ms/step - loss: 0.7931 - accuracy: 1.0000 - val_loss: 1.7144 - val_accuracy: 0.8000
# Epoch 215/250
# 5/5 [==============================] - 0s 68ms/step - loss: 0.7881 - accuracy: 1.0000 - val_loss: 1.6958 - val_accuracy: 0.7857
# Epoch 216/250
# 5/5 [==============================] - 0s 74ms/step - loss: 0.7832 - accuracy: 1.0000 - val_loss: 1.6911 - val_accuracy: 0.7857
# Epoch 217/250
# 5/5 [==============================] - 0s 68ms/step - loss: 0.7784 - accuracy: 1.0000 - val_loss: 1.6860 - val_accuracy: 0.7857
# Epoch 218/250
# 5/5 [==============================] - 0s 73ms/step - loss: 0.7738 - accuracy: 1.0000 - val_loss: 1.6791 - val_accuracy: 0.7714
# Epoch 219/250
# 5/5 [==============================] - 0s 68ms/step - loss: 0.7691 - accuracy: 1.0000 - val_loss: 1.6737 - val_accuracy: 0.7857
# Epoch 220/250
# 5/5 [==============================] - 0s 68ms/step - loss: 0.7645 - accuracy: 1.0000 - val_loss: 1.6727 - val_accuracy: 0.7714
# Epoch 221/250
# 5/5 [==============================] - 0s 67ms/step - loss: 0.7601 - accuracy: 1.0000 - val_loss: 1.6627 - val_accuracy: 0.7857
# Epoch 222/250
# 5/5 [==============================] - 0s 68ms/step - loss: 0.7555 - accuracy: 1.0000 - val_loss: 1.6546 - val_accuracy: 0.7857
# Epoch 223/250
# 5/5 [==============================] - 0s 69ms/step - loss: 0.7511 - accuracy: 1.0000 - val_loss: 1.6624 - val_accuracy: 0.7714
# Epoch 224/250
# 5/5 [==============================] - 0s 70ms/step - loss: 0.7466 - accuracy: 1.0000 - val_loss: 1.6513 - val_accuracy: 0.7857
# Epoch 225/250
# 5/5 [==============================] - 0s 66ms/step - loss: 0.7421 - accuracy: 1.0000 - val_loss: 1.6504 - val_accuracy: 0.7714
# Epoch 226/250
# 5/5 [==============================] - 0s 69ms/step - loss: 0.7378 - accuracy: 1.0000 - val_loss: 1.6395 - val_accuracy: 0.7857
# Epoch 227/250
# 5/5 [==============================] - 0s 72ms/step - loss: 0.7338 - accuracy: 1.0000 - val_loss: 1.6489 - val_accuracy: 0.7714
# Epoch 228/250
# 5/5 [==============================] - 0s 71ms/step - loss: 0.7297 - accuracy: 1.0000 - val_loss: 1.6379 - val_accuracy: 0.7714
# Epoch 229/250
# 5/5 [==============================] - 0s 68ms/step - loss: 0.7256 - accuracy: 1.0000 - val_loss: 1.6344 - val_accuracy: 0.7857
# Epoch 230/250
# 5/5 [==============================] - 0s 68ms/step - loss: 0.7207 - accuracy: 1.0000 - val_loss: 1.6256 - val_accuracy: 0.7714
# Epoch 231/250
# 5/5 [==============================] - 0s 67ms/step - loss: 0.7164 - accuracy: 1.0000 - val_loss: 1.6299 - val_accuracy: 0.7857
# Epoch 232/250
# 5/5 [==============================] - 0s 68ms/step - loss: 0.7124 - accuracy: 1.0000 - val_loss: 1.6241 - val_accuracy: 0.7714
# Epoch 233/250
# 5/5 [==============================] - 0s 70ms/step - loss: 0.7083 - accuracy: 1.0000 - val_loss: 1.6208 - val_accuracy: 0.7714
# Epoch 234/250
# 5/5 [==============================] - 0s 71ms/step - loss: 0.7041 - accuracy: 1.0000 - val_loss: 1.6049 - val_accuracy: 0.7857
# Epoch 235/250
# 5/5 [==============================] - 0s 66ms/step - loss: 0.7003 - accuracy: 1.0000 - val_loss: 1.6141 - val_accuracy: 0.8000
# Epoch 236/250
# 5/5 [==============================] - 0s 68ms/step - loss: 0.6967 - accuracy: 1.0000 - val_loss: 1.6048 - val_accuracy: 0.7857
# Epoch 237/250
# 5/5 [==============================] - 0s 67ms/step - loss: 0.6934 - accuracy: 1.0000 - val_loss: 1.6320 - val_accuracy: 0.7857
# Epoch 238/250
# 5/5 [==============================] - 0s 67ms/step - loss: 0.6898 - accuracy: 1.0000 - val_loss: 1.5917 - val_accuracy: 0.8000
# Epoch 239/250
# 5/5 [==============================] - 0s 68ms/step - loss: 0.6851 - accuracy: 1.0000 - val_loss: 1.6427 - val_accuracy: 0.7857
# Epoch 240/250
# 5/5 [==============================] - 1s 150ms/step - loss: 0.6816 - accuracy: 1.0000 - val_loss: 1.5866 - val_accuracy: 0.7857
# Epoch 241/250
# 5/5 [==============================] - 1s 96ms/step - loss: 0.6779 - accuracy: 1.0000 - val_loss: 1.6326 - val_accuracy: 0.7714
# Epoch 242/250
# 5/5 [==============================] - 0s 69ms/step - loss: 0.6731 - accuracy: 1.0000 - val_loss: 1.5879 - val_accuracy: 0.7857
# Epoch 243/250
# 5/5 [==============================] - 0s 69ms/step - loss: 0.6695 - accuracy: 1.0000 - val_loss: 1.5988 - val_accuracy: 0.7857
# Epoch 244/250
# 5/5 [==============================] - 0s 67ms/step - loss: 0.6655 - accuracy: 1.0000 - val_loss: 1.5868 - val_accuracy: 0.7857
# Epoch 245/250
# 5/5 [==============================] - 0s 70ms/step - loss: 0.6616 - accuracy: 1.0000 - val_loss: 1.5949 - val_accuracy: 0.7571
# Epoch 246/250
# 5/5 [==============================] - 0s 69ms/step - loss: 0.6580 - accuracy: 1.0000 - val_loss: 1.5703 - val_accuracy: 0.7857
# Epoch 247/250
# 5/5 [==============================] - 0s 75ms/step - loss: 0.6544 - accuracy: 1.0000 - val_loss: 1.5858 - val_accuracy: 0.7714
# Epoch 248/250
# 5/5 [==============================] - 0s 70ms/step - loss: 0.6506 - accuracy: 1.0000 - val_loss: 1.5719 - val_accuracy: 0.7857
# Epoch 249/250
# 5/5 [==============================] - 0s 75ms/step - loss: 0.6473 - accuracy: 1.0000 - val_loss: 1.5620 - val_accuracy: 0.7714
# Epoch 250/250
# 5/5 [==============================] - 0s 69ms/step - loss: 0.6443 - accuracy: 1.0000 - val_loss: 1.5652 - val_accuracy: 0.7714

# %% [markdown]
# # Evaluation

# %%
  from sklearn.metrics import accuracy_score
  yhat = model.predict(X_test)
  # round probabilities to class labels
  yhat = yhat.round()
  # calculate accuracy
  acc = accuracy_score(y_test, yhat)
  # store result
  print('Accuracy: %.3f' % acc)
# Out:
# Accuracy: 0.727

# %%
if MODEL == "RNN":
  y_test=y_test.values
  y_pred = model.predict(X_test).round()
  from sklearn.metrics import classification_report
  print(classification_report(y_test, y_pred, zero_division=0, target_names=df_new.columns[1:]))
# Out:
#               precision    recall  f1-score   support
#
#          Aut       0.00      0.00      0.00         0
#        Class       0.00      0.00      0.00         0
#         Itpr       0.59      0.57      0.58        30
#          Lit       0.00      0.00      0.00         0
#         Prec       0.84      0.86      0.85        81
#        Princ       0.46      0.32      0.37        19
#          Psy       0.00      0.00      0.00         0
#         Rule       0.67      0.80      0.73        20
#         Syst       0.00      0.00      0.00         0
#         Tele       0.00      0.00      0.00         0
#
#    micro avg       0.73      0.73      0.73       150
#    macro avg       0.26      0.25      0.25       150
# weighted avg       0.72      0.73      0.72       150
#  samples avg       0.73      0.73      0.73       150

# %% [markdown]
# Saving of test parameters and results on file:

# %%
with open("multilabel_argumentation_type_classification_results.txt", "a") as f:
    f.write("MODEL: " + MODEL + "\n")
    f.write("EMBEDDING: " + EMBEDDING  + "\n")
    f.write("\n")

    f.write("DATASET:\n")
    f.write(str(DATASET["Argumentation_scheme"].value_counts()))
    f.write("\n\n")
    f.write("NUMBER OF SAMPLES: " + str(len(X)) + "\n")
    f.write("TEST_SIZE: " + str(TEST_SIZE*100) + "%\n")
    f.write("\n")

    f.write("PARAMETERS:\n")

    if MODEL == "RNN":
      f.write("EPOCHS: " + str(EPOCHS) + "\n")
      f.write("BATCH_SIZE: " + str(BATCH_SIZE) + "\n")
      f.write("LAYERS: " + str(LAYERS) + "\n")
      f.write("LR: " + str(LR) + "\n")
      f.write("L2_FACTOR: " + str(L2_FACTOR) + "\n")
      f.write("DROP: " + str(DROP) + "\n")
      f.write("\n")

    if MODEL == "BERT":
      f.write("EPOCHS: " + str(EPOCHS) + "\n")
      f.write("BATCH_SIZE: " + str(BATCH_SIZE) + "\n")
      f.write("LR: " + str(LR) + "\n")
      f.write("DROP: " + str(DROP) + "\n")
      f.write("\n")

    if MODEL == "SVC":
      f.write("KERNEL: " + str(KERNEL) + "\n")
      f.write("GAMMA: " + str(GAMMA) + "\n")
      f.write("C: " + str(C) + "\n")
      f.write("DEGREE: " + str(DEGREE) + "\n")
      f.write("\n")

    f.write("RESULTS:\n")
    f.write(classification_report(y_test, y_pred, zero_division=0, target_names=df_new.columns[1:])+"\n")

    f.write("\n")
    f.write("#######################################################")
    f.write("\n\n")
